# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %%
# cfm crossfit men
cfm = pd.read_excel("C:\\Users\\Administrator\\Desktop\\crossfit games dataset\\CrossFit_Games_Athletes_Men_2019.xlsx")
cfm.head(12)
# Out:
#    Game Athletes - Men Unnamed: 1   Unnamed: 2           Unnamed: 3  \
# 0          Year - 2019        NaN          NaN                  NaN
# 1            *********        NaN          NaN                  NaN
# 2                  NaN        NaN          NaN                  NaN
# 3                  NaN        NaN          NaN                  NaN
# 4                  NaN        NaN          NaN                  NaN
# 5                  NaN        NaN          NaN                  NaN
# 6                  NaN        NaN          NaN                  NaN
# 7                  NaN        NaN          NaN                  NaN
# 8                  NaN        NaN          NaN                  NaN
# 9                  NaN     height  affiliateid  countryoforiginname
# 10                 NaN       1.74        44632        United States
# 11                 NaN       1.74        44800        United States
#
#    Unnamed: 4         Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
cfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Game Athletes - Men  2 non-null      object
#  1   Unnamed: 1           204 non-null    object
#  2   Unnamed: 2           183 non-null    object
#  3   Unnamed: 3           204 non-null    object
#  4   Unnamed: 4           204 non-null    object
#  5   Unnamed: 5           183 non-null    object
#  6   Unnamed: 6           204 non-null    object
#  7   Unnamed: 7           204 non-null    object
#  8   Unnamed: 8           204 non-null    object
#  9   Unnamed: 9           204 non-null    object
#  10  Unnamed: 10          204 non-null    object
#  11  Unnamed: 11          204 non-null    object
#  12  Unnamed: 12          204 non-null    object
#  13  Unnamed: 13          204 non-null    object
#  14  Unnamed: 14          204 non-null    object
# ...

# %%
cfm.index
# Out:
# RangeIndex(start=0, stop=213, step=1)

# %%
cfm.columns
# Out:
# Index(['Game Athletes - Men', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
# cfm.drop([0,1,2,3,4,5,6,7,8], axis = 1, inplace = True)
cfm
# Out:
#     Game Athletes - Men Unnamed: 1   Unnamed: 2           Unnamed: 3  \
# 9                   NaN     height  affiliateid  countryoforiginname
# 10                  NaN       1.74        44632        United States
# 11                  NaN       1.74        44800        United States
# 12                  NaN       1.55        44753              Iceland
# 13                  NaN        1.8        44597        United States
# ..                  ...        ...          ...                  ...
# 208                 NaN       1.77        44939        United States
# 209                 NaN       1.55        44853        United States
# 210                 NaN       1.56        44890        United States
# 211                 NaN       1.55        44949        United States
# 212                 NaN       1.77        44815        United States
#
#     Unnamed: 4                 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 9       weight              affiliatename     status      bibid
# ...

# %%
cfm.drop(["Game Athletes - Men"], axis = 1, inplace = True)
cfm
# Out:
#     Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 9       height  affiliateid  countryoforiginname     weight
# 10        1.74        44632        United States       88.5
# 11        1.74        44800        United States       86.2
# 12        1.55        44753              Iceland       83.9
# 13         1.8        44597        United States       84.8
# ..         ...          ...                  ...        ...
# 208       1.77        44939        United States       73.9
# 209       1.55        44853        United States       81.6
# 210       1.56        44890        United States       79.4
# 211       1.55        44949        United States       72.6
# 212       1.77        44815        United States       74.8
#
#                     Unnamed: 5 Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# 9                affiliatename     status      bibid          profilepics3key
# 10             CrossFit Mayhem        ACT         16  9e218-P153604_4-184.jpg
# ...

# %%
cfm.columns = cfm.iloc[0]
cfm
# Out:
# 9    height  affiliateid  countryoforiginname  weight  \
# 9    height  affiliateid  countryoforiginname  weight
# 10     1.74        44632        United States    88.5
# 11     1.74        44800        United States    86.2
# 12     1.55        44753              Iceland    83.9
# 13      1.8        44597        United States    84.8
# ..      ...          ...                  ...     ...
# 208    1.77        44939        United States    73.9
# 209    1.55        44853        United States    81.6
# 210    1.56        44890        United States    79.4
# 211    1.55        44949        United States    72.6
# 212    1.77        44815        United States    74.8
#
# 9                affiliatename  status  bibid          profilepics3key  \
# 9                affiliatename  status  bibid          profilepics3key
# 10             CrossFit Mayhem     ACT     16  9e218-P153604_4-184.jpg
# 11           Peak 360 CrossFit     ACT    302    0a0bc-P2725_5-184.jpg
# ...

# %%
cfm.drop([9], axis = 0, inplace = True)
cfm
# Out:
# 9   height affiliateid countryoforiginname weight              affiliatename  \
# 10    1.74       44632       United States   88.5            CrossFit Mayhem
# 11    1.74       44800       United States   86.2          Peak 360 CrossFit
# 12    1.55       44753             Iceland   83.9           CrossFit Hengill
# 13     1.8       44597       United States   84.8         CrossFit Mentality
# 14    1.55       44792           Australia   87.1              CrossFit Mode
# ..     ...         ...                 ...    ...                        ...
# 208   1.77       44939       United States   73.9          CrossFit SolaFide
# 209   1.55       44853       United States   81.6  The Arena Nevada CrossFit
# 210   1.56       44890       United States   79.4       Double Down CrossFit
# 211   1.55       44949       United States   72.6          CrossFit Beaufort
# 212   1.77       44815       United States   74.8    CrossFit Dallas Central
#
# ...

# %%
cfm.columns.name = "S/N"
cfm
# Out:
# S/N height affiliateid countryoforiginname weight              affiliatename  \
# 10    1.74       44632       United States   88.5            CrossFit Mayhem
# 11    1.74       44800       United States   86.2          Peak 360 CrossFit
# 12    1.55       44753             Iceland   83.9           CrossFit Hengill
# 13     1.8       44597       United States   84.8         CrossFit Mentality
# 14    1.55       44792           Australia   87.1              CrossFit Mode
# ..     ...         ...                 ...    ...                        ...
# 208   1.77       44939       United States   73.9          CrossFit SolaFide
# 209   1.55       44853       United States   81.6  The Arena Nevada CrossFit
# 210   1.56       44890       United States   79.4       Double Down CrossFit
# 211   1.55       44949       United States   72.6          CrossFit Beaufort
# 212   1.77       44815       United States   74.8    CrossFit Dallas Central
#
# ...

# %%
cfm.set_index(np.arange(1,204), inplace = True)
cfm
# Out:
# S/N height affiliateid countryoforiginname weight              affiliatename  \
# 1     1.74       44632       United States   88.5            CrossFit Mayhem
# 2     1.74       44800       United States   86.2          Peak 360 CrossFit
# 3     1.55       44753             Iceland   83.9           CrossFit Hengill
# 4      1.8       44597       United States   84.8         CrossFit Mentality
# 5     1.55       44792           Australia   87.1              CrossFit Mode
# ..     ...         ...                 ...    ...                        ...
# 199   1.77       44939       United States   73.9          CrossFit SolaFide
# 200   1.55       44853       United States   81.6  The Arena Nevada CrossFit
# 201   1.56       44890       United States   79.4       Double Down CrossFit
# 202   1.55       44949       United States   72.6          CrossFit Beaufort
# 203   1.77       44815       United States   74.8    CrossFit Dallas Central
#
# ...

# %%
cfm["affiliateid"] = cfm["affiliateid"].fillna("NO_ID")

# %%
cfm["affiliatename"] = cfm["affiliatename"].fillna("NO_NAME")

# %%
overall_score_null = cfm["competitorid"][cfm["overallscore"].isnull()]
overall_score_null
# Out:
# 143      18543
# 144    1382942
# 154      25569
# Name: competitorid, dtype: object

# %%
scores = pd.read_excel("C:\\Users\\Administrator\\Desktop\\crossfit games dataset\\CrossFit_Games_Scores_2019.xlsx")
scores.head()
# Out:
#    ordinal breakdown  lane rank  heat  points     scoredisplay  \
# 0        1   100 pts    26    1     3     100  00:15:07.700000
# 1        2   100 pts    20    1     2     100  00:05:37.020000
# 2        3    68 pts    25   17     1      68  00:25:50.090000
# 3        4    40 pts    10   21     2      40  00:01:50.080000
# 4        5    96 pts     8    2     2      96          675 rep
#
#               time workoutrank  competitorid  Number of Records
# 0  00:15:07.700000           1        153604                  1
# 1  00:05:37.020000           1        153604                  1
# 2  00:25:50.090000          17        153604                  1
# 3  00:01:50.080000          21        153604                  1
# 4              675           2        153604                  1

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ordinal            4213 non-null   int64
#  1   breakdown          1700 non-null   object
#  2   lane               4213 non-null   int64
#  3   rank               4213 non-null   object
#  4   heat               4213 non-null   int64
#  5   points             4213 non-null   int64
#  6   scoredisplay       1700 non-null   object
#  7   time               1700 non-null   object
#  8   workoutrank        4213 non-null   object
#  9   competitorid       4213 non-null   int64
#  10  Number of Records  4213 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 362.2+ KB

# %%
point_1 = scores["points"][scores["competitorid"] == 18543]
point_1
# Out:
# 1704    0
# 1705    0
# 1706    0
# 1707    0
# 1708    0
# 1709    0
# 1710    0
# 1711    0
# 1712    0
# 1713    0
# 1714    0
# 1715    0
# Name: points, dtype: int64

# %%
point_2 = scores["points"][scores["competitorid"] == 1382942]
point_2
# Out:
# 1716    0
# 1717    0
# 1718    0
# 1719    0
# 1720    0
# 1721    0
# 1722    0
# 1723    0
# 1724    0
# 1725    0
# 1726    0
# 1727    0
# Name: points, dtype: int64

# %%
point_3 = scores["points"][scores["competitorid"] == 25569]
point_3
# Out:
# 3372    0
# 3373    0
# 3374    0
# 3375    0
# 3376    0
# 3377    0
# 3378    0
# 3379    0
# Name: points, dtype: int64

# %%
cfm["overallscore"] = cfm["overallscore"].fillna(0)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16948\52000062.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cfm["overallscore"] = cfm["overallscore"].fillna(0)

# %%
cfm
# Out:
# S/N height affiliateid countryoforiginname weight              affiliatename  \
# 1     1.74       44632       United States   88.5            CrossFit Mayhem
# 2     1.74       44800       United States   86.2          Peak 360 CrossFit
# 3     1.55       44753             Iceland   83.9           CrossFit Hengill
# 4      1.8       44597       United States   84.8         CrossFit Mentality
# 5     1.55       44792           Australia   87.1              CrossFit Mode
# ..     ...         ...                 ...    ...                        ...
# 199   1.77       44939       United States   73.9          CrossFit SolaFide
# 200   1.55       44853       United States   81.6  The Arena Nevada CrossFit
# 201   1.56       44890       United States   79.4       Double Down CrossFit
# 202   1.55       44949       United States   72.6          CrossFit Beaufort
# 203   1.77       44815       United States   74.8    CrossFit Dallas Central
#
# ...

# %%
cfm.iloc[144:,10] = "NO_GENDER_XY"
cfm
# Out:
# S/N height affiliateid countryoforiginname weight              affiliatename  \
# 1     1.74       44632       United States   88.5            CrossFit Mayhem
# 2     1.74       44800       United States   86.2          Peak 360 CrossFit
# 3     1.55       44753             Iceland   83.9           CrossFit Hengill
# 4      1.8       44597       United States   84.8         CrossFit Mentality
# 5     1.55       44792           Australia   87.1              CrossFit Mode
# ..     ...         ...                 ...    ...                        ...
# 199   1.77       44939       United States   73.9          CrossFit SolaFide
# 200   1.55       44853       United States   81.6  The Arena Nevada CrossFit
# 201   1.56       44890       United States   79.4       Double Down CrossFit
# 202   1.55       44949       United States   72.6          CrossFit Beaufort
# 203   1.77       44815       United States   74.8    CrossFit Dallas Central
#
# ...

# %%
cfm.head(148)
# Out:
# S/N height affiliateid countryoforiginname weight       affiliatename status  \
# 1     1.74       44632       United States   88.5     CrossFit Mayhem    ACT
# 2     1.74       44800       United States   86.2   Peak 360 CrossFit    ACT
# 3     1.55       44753             Iceland   83.9    CrossFit Hengill    ACT
# 4      1.8       44597       United States   84.8  CrossFit Mentality    ACT
# 5     1.55       44792           Australia   87.1       CrossFit Mode    ACT
# ..     ...         ...                 ...    ...                 ...    ...
# 144   1.55       44738                Oman   91.2      CrossFit Tempo     WD
# 145   1.55       44852       United States   87.1        CrossFit 061    ACT
# 146   1.55       44880       United States   83.9       CrossFit Rage    ACT
# 147   1.55       44875             Iceland   91.2   CrossFit Akureyri    ACT
# 148   1.77       44925              France   91.6    CrossFit Saintes    ACT
#
# ...

# %%
age_of_range = [20,25,30,35,40,45,50,55,60,65]
age_label = ["20-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "55-59", "60-64"]

# %%
cfm["age_range"] = pd.cut(cfm["age"], bins = age_of_range, labels = age_label, right = False)
cfm
# Out:
# S/N height affiliateid countryoforiginname weight              affiliatename  \
# 1     1.74       44632       United States   88.5            CrossFit Mayhem
# 2     1.74       44800       United States   86.2          Peak 360 CrossFit
# 3     1.55       44753             Iceland   83.9           CrossFit Hengill
# 4      1.8       44597       United States   84.8         CrossFit Mentality
# 5     1.55       44792           Australia   87.1              CrossFit Mode
# ..     ...         ...                 ...    ...                        ...
# 199   1.77       44939       United States   73.9          CrossFit SolaFide
# 200   1.55       44853       United States   81.6  The Arena Nevada CrossFit
# 201   1.56       44890       United States   79.4       Double Down CrossFit
# 202   1.55       44949       United States   72.6          CrossFit Beaufort
# 203   1.77       44815       United States   74.8    CrossFit Dallas Central
#
# ...

# %%
most_athletes = cfm["countryoforigincode"].value_counts()
most_athletes.nlargest(10)
# Out:
# countryoforigincode
# US    68
# CA    11
# AU     5
# IS     4
# SE     3
# GB     3
# IT     3
# PL     2
# CH     2
# BR     2
# Name: count, dtype: int64

# %%
most_athletes = most_athletes.nlargest(10)

# %%
plt.bar(most_athletes.index, most_athletes.values)
plt.title("COUNTRY AND THE NUMBER OF ATHLETES")
plt.xlabel("COUNTRY")
plt.ylabel("NUMBER OF ATHLETES")
plt.show()

# %%
cfm["overallrank"].dtype
# Out:
# dtype('O')

# %%
most_successful = cfm.iloc[:20].groupby("countryoforiginname")["overallrank"].count()
most_successful
# Out:
# countryoforiginname
# Australia          2
# Canada             1
# Denmark            1
# Germany            1
# Iceland            1
# Sweden             1
# Switzerland        1
# United Kingdom     1
# United States     11
# Name: overallrank, dtype: int64

# %%
fig = px.bar(most_successful, title = "THE COUNTRIES OCCUPYING THE FIRST 10 RANK")
fig.update_layout(xaxis_title = "COUNTRY", yaxis_title = "NUMBER OF ATHLETES IN THE FIRST 10 RANK")
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_99.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
peak_age = cfm.iloc[:40].groupby("age_range")["overallrank"].count()
peak_age
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16948\2944676755.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# age_range
# 20-24     6
# 25-29    29
# 30-34     4
# 35-39     1
# 40-44     0
# 45-49     0
# 50-54     0
# 55-59     0
# 60-64     0
# Name: overallrank, dtype: int64

# %%
fig = px.bar(peak_age, title = "THE AGE RANGE OF THE COMPETITORS WITH PEAK PERFORMANCE")
fig.update_layout(xaxis_title = "AGE RANGE", yaxis_title = "NUMBER OF ATHLETES IN THE FIRST 40 RANK")
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_103.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
most_age = cfm.iloc[:50].groupby("age")["overallrank"].count()
most_age
# Out:
# age
# 19     1
# 20     1
# 21     1
# 22     1
# 23     3
# 24     1
# 25     3
# 26    10
# 27     4
# 28    11
# 29     6
# 30     3
# 31     3
# 33     1
# 35     1
# Name: overallrank, dtype: int64

# %%
fig = px.bar(most_age, title = "AGE OF COMPETITORS WITH PEAK PERFORMANCE")
fig.update_layout(xaxis_title = "AGE", yaxis_title = "NUMBER OF ATHLETES IN THE FIRST 50 RANK")
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_207.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
successful_gym = cfm.groupby("affiliatename")["overallrank"].count()

# %%
successful_gym.nlargest()
# Out:
# affiliatename
# NO_NAME              21
# CrossFit Invictus     3
# CrossFit Alioth       2
# CrossFit Dignus       2
# CrossFit Kreis 9      2
# Name: overallrank, dtype: int64

# %%
import plotly.express as px
fig = px.bar(successful_gym.nlargest())
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_119.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# cfw crossfit women
cfw = pd.read_excel("C:\\Users\\Administrator\\Desktop\\crossfit games dataset\\CrossFit_Games_Athletes_Women_2019.xlsx")
cfw.head(12)
# Out:
#    Game Athletes - Women Unnamed: 1   Unnamed: 2           Unnamed: 3  \
# 0            Year - 2019        NaN          NaN                  NaN
# 1              *********        NaN          NaN                  NaN
# 2                    NaN        NaN          NaN                  NaN
# 3                    NaN        NaN          NaN                  NaN
# 4                    NaN        NaN          NaN                  NaN
# 5                    NaN        NaN          NaN                  NaN
# 6                    NaN        NaN          NaN                  NaN
# 7                    NaN        NaN          NaN                  NaN
# 8                    NaN     height  affiliateid  countryoforiginname
# 9                    NaN       1.65        44632            Australia
# 10                   NaN       1.65        44731               Norway
# 11                   NaN       1.65        44663          New Zealand
#
# ...

# %%
cfw.drop([0,1,2,3,4,5,6,7], axis = 0, inplace = True)
cfw.drop(["Game Athletes - Women"], axis = 1, inplace = True)
cfw
# Out:
#     Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 8       height  affiliateid  countryoforiginname     weight
# 9         1.65        44632            Australia       58.1
# 10        1.65        44731               Norway         59
# 11        1.65        44663          New Zealand       61.2
# 12        1.74        44608              Iceland         68
# ..         ...          ...                  ...        ...
# 195       1.65        44947        United States       71.2
# 196       1.62        44856        United States       53.1
# 197       1.25        44782        United States       50.8
# 198       1.68        44821               Canada       57.2
# 199       1.68        44907               Canada       55.8
#
#                          Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 8                     affiliatename     status      bibid
# 9                   CrossFit Mayhem        ACT         17
# 10                    CrossFit Oslo        ACT        122
# ...

# %%
cfw.columns = cfw.iloc[0]
cfw.drop([8], axis = 0, inplace = True)
cfw
# Out:
# 8   height affiliateid countryoforiginname weight  \
# 9     1.65       44632           Australia   58.1
# 10    1.65       44731              Norway     59
# 11    1.65       44663         New Zealand   61.2
# 12    1.74       44608             Iceland     68
# 13    1.62       44589       United States     63
# ..     ...         ...                 ...    ...
# 195   1.65       44947       United States   71.2
# 196   1.62       44856       United States   53.1
# 197   1.25       44782       United States   50.8
# 198   1.68       44821              Canada   57.2
# 199   1.68       44907              Canada   55.8
#
# 8                     affiliatename status bibid          profilepics3key  \
# 9                   CrossFit Mayhem    ACT    17  b8a69-P163097_3-184.jpg
# 10                    CrossFit Oslo    ACT   122  df164-P120480_7-184.jpg
# 11                     CrossFit Yas    ACT   123  101af-P264512_2-184.jpg
# ...

# %%
cfw.columns.name = "S/N"
cfw
# Out:
# S/N height affiliateid countryoforiginname weight  \
# 9     1.65       44632           Australia   58.1
# 10    1.65       44731              Norway     59
# 11    1.65       44663         New Zealand   61.2
# 12    1.74       44608             Iceland     68
# 13    1.62       44589       United States     63
# ..     ...         ...                 ...    ...
# 195   1.65       44947       United States   71.2
# 196   1.62       44856       United States   53.1
# 197   1.25       44782       United States   50.8
# 198   1.68       44821              Canada   57.2
# 199   1.68       44907              Canada   55.8
#
# S/N                   affiliatename status bibid          profilepics3key  \
# 9                   CrossFit Mayhem    ACT    17  b8a69-P163097_3-184.jpg
# 10                    CrossFit Oslo    ACT   122  df164-P120480_7-184.jpg
# 11                     CrossFit Yas    ACT   123  101af-P264512_2-184.jpg
# ...

# %%
cfw.set_index(np.arange(1,192), inplace = True)
cfw
# Out:
# S/N height affiliateid countryoforiginname weight  \
# 1     1.65       44632           Australia   58.1
# 2     1.65       44731              Norway     59
# 3     1.65       44663         New Zealand   61.2
# 4     1.74       44608             Iceland     68
# 5     1.62       44589       United States     63
# ..     ...         ...                 ...    ...
# 187   1.65       44947       United States   71.2
# 188   1.62       44856       United States   53.1
# 189   1.25       44782       United States   50.8
# 190   1.68       44821              Canada   57.2
# 191   1.68       44907              Canada   55.8
#
# S/N                   affiliatename status bibid          profilepics3key  \
# 1                   CrossFit Mayhem    ACT    17  b8a69-P163097_3-184.jpg
# 2                     CrossFit Oslo    ACT   122  df164-P120480_7-184.jpg
# 3                      CrossFit Yas    ACT   123  101af-P264512_2-184.jpg
# ...

# %%
cfw.isnull().sum()
# Out:
# S/N
# height                 0
# affiliateid            0
# countryoforiginname    0
# weight                 0
# affiliatename          0
# status                 0
# bibid                  0
# profilepics3key        0
# competitorid           0
# firstname              0
# gender                 0
# age                    0
# lastname               0
# countryoforigincode    0
# competitorname         0
# overallrank            0
# overallscore           0
# division               0
# Number of Records      0
# dtype: int64

# %%
cfw["affiliateid"] = cfw["affiliateid"].fillna("NO_ID")
cfw["affiliatename"] = cfw["affiliatename"].fillna("NO_NAME")

# %%
cfw["countryoforiginname"][cfw["countryoforigincode"].isnull()]
# Out:
# Series([], Name: countryoforiginname, dtype: object)

# %%
cfw["countryoforigincode"] = cfw["countryoforigincode"].fillna("NAN")

# %%
cfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 1 to 191
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   height               191 non-null    object
#  1   affiliateid          191 non-null    object
#  2   countryoforiginname  191 non-null    object
#  3   weight               191 non-null    object
#  4   affiliatename        191 non-null    object
#  5   status               191 non-null    object
#  6   bibid                191 non-null    object
#  7   profilepics3key      191 non-null    object
#  8   competitorid         191 non-null    object
#  9   firstname            191 non-null    object
#  10  gender               191 non-null    object
#  11  age                  191 non-null    object
#  12  lastname             191 non-null    object
#  13  countryoforigincode  191 non-null    object
#  14  competitorname       191 non-null    object
# ...

# %%
cfw.iloc[131:,10] = "NO_GENDER_XX"
cfw
# Out:
# S/N height affiliateid countryoforiginname weight  \
# 1     1.65       44632           Australia   58.1
# 2     1.65       44731              Norway     59
# 3     1.65       44663         New Zealand   61.2
# 4     1.74       44608             Iceland     68
# 5     1.62       44589       United States     63
# ..     ...         ...                 ...    ...
# 187   1.65       44947       United States   71.2
# 188   1.62       44856       United States   53.1
# 189   1.25       44782       United States   50.8
# 190   1.68       44821              Canada   57.2
# 191   1.68       44907              Canada   55.8
#
# S/N                   affiliatename status bibid          profilepics3key  \
# 1                   CrossFit Mayhem    ACT    17  b8a69-P163097_3-184.jpg
# 2                     CrossFit Oslo    ACT   122  df164-P120480_7-184.jpg
# 3                      CrossFit Yas    ACT   123  101af-P264512_2-184.jpg
# ...

# %%
age_of_range_women = [20,25,30,35,40,45,50,55,60,65]
age_label_women = ["20-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "55-59", "60-64"]

# %%
cfw["age_range"] = pd.cut(cfw["age"], bins = age_of_range_women, labels = age_label_women, right = False)
cfw
# Out:
# S/N height affiliateid countryoforiginname weight  \
# 1     1.65       44632           Australia   58.1
# 2     1.65       44731              Norway     59
# 3     1.65       44663         New Zealand   61.2
# 4     1.74       44608             Iceland     68
# 5     1.62       44589       United States     63
# ..     ...         ...                 ...    ...
# 187   1.65       44947       United States   71.2
# 188   1.62       44856       United States   53.1
# 189   1.25       44782       United States   50.8
# 190   1.68       44821              Canada   57.2
# 191   1.68       44907              Canada   55.8
#
# S/N                   affiliatename status bibid          profilepics3key  \
# 1                   CrossFit Mayhem    ACT    17  b8a69-P163097_3-184.jpg
# 2                     CrossFit Oslo    ACT   122  df164-P120480_7-184.jpg
# 3                      CrossFit Yas    ACT   123  101af-P264512_2-184.jpg
# ...

# %%
most_women_athletes = cfw["countryoforigincode"].value_counts()
most_women_athletes
# Out:
# countryoforigincode
# US    55
# CA    12
# AU     8
# NZ     5
# IS     5
#       ..
# UA     1
# IN     1
# AT     1
# PH     1
# MU     1
# Name: count, Length: 96, dtype: int64

# %%
most_women_athletes = most_women_athletes.nlargest(10)
most_women_athletes
# Out:
# countryoforigincode
# US    55
# CA    12
# AU     8
# NZ     5
# IS     5
# SE     5
# FR     3
# GB     3
# RU     2
# NO     2
# Name: count, dtype: int64

# %%
fig = px.bar(most_women_athletes, title="COUNTRY WITH THE HIGHEST NUMBER ATHLETES")
fig.update_layout(xaxis_title = "COUNTRY", yaxis_title = "NUMBER OF ATHLETES")
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_183.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
most_successful_women = cfw.iloc[:20].groupby("countryoforiginname")["overallrank"].count()

# %%
most_successful_women
# Out:
# countryoforiginname
# Australia         1
# Canada            3
# Greece            1
# Hungary           1
# Iceland           4
# Italy             1
# New Zealand       1
# Norway            1
# United Kingdom    1
# United States     6
# Name: overallrank, dtype: int64

# %%
fig = px.bar(most_successful_women, title = "THE COUNTRIES OCCUPYING THE FIRST 10 RANK")
fig.update_layout(xaxis_title = "COUNTRY", yaxis_title = "NUMBER OF ATHLETES IN THE FIRST 10 RANK")
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_189.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
peak_age_women = cfw.iloc[:40].groupby("age_range")["overallrank"].count()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16948\3213132047.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
peak_age_women
# Out:
# age_range
# 20-24     8
# 25-29    20
# 30-34    10
# 35-39     1
# 40-44     0
# 45-49     0
# 50-54     0
# 55-59     0
# 60-64     0
# Name: overallrank, dtype: int64

# %%
fig = px.bar(peak_age_women, title = "AGE RANGE OF WOMEN COMPETITORS WITH PEAK PERFORMANCE")
fig.update_layout(xaxis_title = "AGE RANGE", yaxis_title = "NUMBER OF ATHLETES IN THE FIRST 40 RANK")
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_197.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
most_age_women = cfw.iloc[:50].groupby("age")["overallrank"].count()
most_age_women
# Out:
# age
# 18    1
# 22    2
# 23    2
# 24    4
# 25    5
# 26    4
# 27    9
# 28    3
# 29    5
# 30    7
# 31    2
# 32    1
# 33    2
# 34    2
# 37    1
# Name: overallrank, dtype: int64

# %%
fig = px.bar(most_age_women, title = "AGE OF COMPETITORS WITH PEAK PERFORMANCE")
fig.update_layout(xaxis_title = "AGE", yaxis_title = "NUMBER OF ATHLETES IN THE FIRST 50 RANK")
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_203.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
successful_gym = cfw.groupby("affiliatename")["overallrank"].count()

# %%
successful_gym.nlargest()
# Out:
# affiliatename
# NO_NAME              16
# CrossFit Active       3
# CrossFit Majestic     2
# CrossFit Mayhem       2
# Crucible CrossFit     2
# Name: overallrank, dtype: int64

# %%
import plotly.express as px
fig = px.bar(successful_gym.nlargest())
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_221.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
